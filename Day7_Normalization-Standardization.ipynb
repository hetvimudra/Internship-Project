# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/hetvi/Desktop/15-Days Internship/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.iloc[:,3:6]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
df["Age"].fillna(0,inplace=True)

# %%
df.drop(df.iloc[:,2:5],axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived   Age  SibSp  Parch            Ticket     Fare  \
# 0              1         0  22.0      1      0         A/5 21171   7.2500
# 1              2         1  38.0      1      0          PC 17599  71.2833
# 2              3         1  26.0      0      0  STON/O2. 3101282   7.9250
# 3              4         1  35.0      1      0            113803  53.1000
# 4              5         0  35.0      0      0            373450   8.0500
# ..           ...       ...   ...    ...    ...               ...      ...
# 886          887         0  27.0      0      0            211536  13.0000
# 887          888         1  19.0      0      0            112053  30.0000
# 888          889         0   0.0      1      2        W./C. 6607  23.4500
# 889          890         1  26.0      0      0            111369  30.0000
# 890          891         0  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     NaN        S
# 1     C85        C
# ...

# %%
df.drop(df.iloc[:,3:6],axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived   Age     Fare Cabin Embarked
# 0              1         0  22.0   7.2500   NaN        S
# 1              2         1  38.0  71.2833   C85        C
# 2              3         1  26.0   7.9250   NaN        S
# 3              4         1  35.0  53.1000  C123        S
# 4              5         0  35.0   8.0500   NaN        S
# ..           ...       ...   ...      ...   ...      ...
# 886          887         0  27.0  13.0000   NaN        S
# 887          888         1  19.0  30.0000   B42        S
# 888          889         0   0.0  23.4500   NaN        S
# 889          890         1  26.0  30.0000  C148        C
# 890          891         0  32.0   7.7500   NaN        Q
#
# [891 rows x 6 columns]

# %%
df.drop(df.iloc[:,4:],axis=1,inplace=True)

# %%
df.drop(df.iloc[:,0:1],axis=1,inplace=True)

# %%
df
# Out:
#      Survived   Age     Fare
# 0           0  22.0   7.2500
# 1           1  38.0  71.2833
# 2           1  26.0   7.9250
# 3           1  35.0  53.1000
# 4           0  35.0   8.0500
# ..        ...   ...      ...
# 886         0  27.0  13.0000
# 887         1  19.0  30.0000
# 888         0   0.0  23.4500
# 889         1  26.0  30.0000
# 890         0  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(["Survived"],axis=1),df["Survived"],test_size=0.3,random_state=42)

# %%
x_train
# Out:
#       Age      Fare
# 445   4.0   81.8583
# 650   0.0    7.8958
# 172   1.0   11.1333
# 450  36.0   27.7500
# 314  43.0   26.2500
# ..    ...       ...
# 106  21.0    7.6500
# 270   0.0   31.0000
# 860  41.0   14.1083
# 435  14.0  120.0000
# 102  21.0   77.2875
#
# [623 rows x 2 columns]

# %%
x_test
# Out:
#       Age     Fare
# 709   0.0  15.2458
# 439  31.0  10.5000
# 840  20.0   7.9250
# 720   6.0  33.0000
# 39   14.0  11.2417
# ..    ...      ...
# 821  27.0   8.6625
# 633   0.0   0.0000
# 456  65.0  26.5500
# 500  17.0   8.6625
# 430  28.0  26.5500
#
# [268 rows x 2 columns]

# %%
y_train
# Out:
# 445    1
# 650    0
# 172    1
# 450    0
# 314    0
#       ..
# 106    1
# 270    0
# 860    0
# 435    1
# 102    0
# Name: Survived, Length: 623, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()

# %%
x_train_Scaler=st.fit_transform(x_train)
x_test_Scaler=st.transform(x_test)

# %%
x_train_Scaler
# Out:
# array([[-1.11114426,  0.98099823],
#        [-1.33985407, -0.46963364],
#        [-1.28267662, -0.40613632],
#        ...,
#        [ 1.00442157, -0.34778742],
#        [-0.53936971,  1.72907416],
#        [-0.13912752,  0.8913508 ]])

# %%
x_train_Scaler=pd.DataFrame(x_train_Scaler,columns=x_train.columns)

# %%
x_train_Scaler.describe()
# Out:
#                 Age          Fare
# count  6.230000e+02  6.230000e+02
# mean  -5.417461e-17 -2.851295e-18
# std    1.000804e+00  1.000804e+00
# min   -1.339854e+00 -6.244945e-01
# 25%   -1.111144e+00 -4.690609e-01
# 50%    3.240484e-02 -3.410033e-01
# 75%    6.613568e-01 -2.139256e-02
# max    3.234342e+00  9.423855e+00

# %%
np.round(x_train_Scaler.describe(),1)
# Out:
#          Age   Fare
# count  623.0  623.0
# mean    -0.0   -0.0
# std      1.0    1.0
# min     -1.3   -0.6
# 25%     -1.1   -0.5
# 50%      0.0   -0.3
# 75%      0.7   -0.0
# max      3.2    9.4

# %%
import matplotlib.pyplot as plt

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_train["Age"],x_train["Fare"])
a1.set_title("Before scaling")
a2.scatter(x_train_Scaler["Age"],x_train_Scaler["Fare"],color="red")
a2.set_title("After scaling")
#plt.show()
# Out:
# Text(0.5, 1.0, 'After scaling')

# %%
plt.scatter(x_train["Age"],x_train["Fare"])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m=MinMaxScaler()

# %%
x_train_Scaler=m.fit_transform(x_train)
x_test_Scaler=m.transform(x_test)

# %%
x_train_Scaler
# Out:
# array([[0.05      , 0.15977676],
#        [0.        , 0.01541158],
#        [0.0125    , 0.02173075],
#        ...,
#        [0.5125    , 0.02753757],
#        [0.175     , 0.2342244 ],
#        [0.2625    , 0.15085515]])

# %%
x_train_Scaler=pd.DataFrame(x_train_Scaler,columns=x_train.columns)

# %%
x_train_Scaler.describe()
# Out:
#               Age        Fare
# count  623.000000  623.000000
# mean     0.292916    0.062149
# std      0.218793    0.099599
# min      0.000000    0.000000
# 25%      0.050000    0.015469
# 50%      0.300000    0.028213
# 75%      0.437500    0.060020
# max      1.000000    1.000000

# %%
np.round(x_train_Scaler.describe(),1)
# Out:
#          Age   Fare
# count  623.0  623.0
# mean     0.3    0.1
# std      0.2    0.1
# min      0.0    0.0
# 25%      0.0    0.0
# 50%      0.3    0.0
# 75%      0.4    0.1
# max      1.0    1.0

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_train["Age"],x_train["Fare"])
a1.set_title("Before scaling")
a2.scatter(x_train_Scaler["Age"],x_train_Scaler["Fare"],color="red")
a2.set_title("After scaling")
plt.show()

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
m=MaxAbsScaler()

# %%
x_train_Scaler=m.fit_transform(x_train)
x_test_Scaler=m.transform(x_test)

# %%
x_train_Scaler=pd.DataFrame(x_train_Scaler,columns=x_train.columns)

# %%
x_train_Scaler.describe()
# Out:
#               Age        Fare
# count  623.000000  623.000000
# mean     0.292916    0.062149
# std      0.218793    0.099599
# min      0.000000    0.000000
# 25%      0.050000    0.015469
# 50%      0.300000    0.028213
# 75%      0.437500    0.060020
# max      1.000000    1.000000

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_train["Age"],x_train["Fare"])
a1.set_title("Before scaling")
a2.scatter(x_train_Scaler["Age"],x_train_Scaler["Fare"],color="red")
a2.set_title("After scaling")
plt.show()

# %%
from sklearn.preprocessing import RobustScaler

# %%
r=RobustScaler()

# %%
x_train_Scaler=r.fit_transform(x_train)
x_test_Scaler=r.transform(x_test)

# %%
x_train_Scaler=pd.DataFrame(x_train_Scaler,columns=x_train.columns)

# %%
x_train_Scaler.describe()
# Out:
#               Age        Fare
# count  623.000000  623.000000
# mean    -0.018282    0.761732
# std      0.564628    2.235591
# min     -0.774194   -0.633262
# 25%     -0.645161   -0.286055
# 50%      0.000000    0.000000
# 75%      0.354839    0.713945
# max      1.806452   21.812705

# %%
np.round(x_train_Scaler.describe(),1)
# Out:
#          Age   Fare
# count  623.0  623.0
# mean    -0.0    0.8
# std      0.6    2.2
# min     -0.8   -0.6
# 25%     -0.6   -0.3
# 50%      0.0    0.0
# 75%      0.4    0.7
# max      1.8   21.8

# %%
fig,(a1,a2)=plt.subplots(ncols=2,figsize=(12,5))
a1.scatter(x_train["Age"],x_train["Fare"])
a1.set_title("Before scaling")
a2.scatter(x_train_Scaler["Age"],x_train_Scaler["Fare"],color="red")
a2.set_title("After scaling")
plt.show()
