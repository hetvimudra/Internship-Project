# %% [markdown]
# # Task

# %%
# Apply all graphs in your selected dataset..

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/hetvi/Desktop/15-Days Internship/USA_cars_datasets.csv")

# %%
df
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
#df.fillna(0,axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2499 non-null   int64
#  1   price         2499 non-null   int64
#  2   brand         2499 non-null   object
#  3   model         2499 non-null   object
#  4   year          2499 non-null   int64
#  5   title_status  2499 non-null   object
#  6   mileage       2499 non-null   float64
#  7   color         2499 non-null   object
#  8   vin           2499 non-null   object
#  9   lot           2499 non-null   int64
#  10  state         2499 non-null   object
#  11  country       2499 non-null   object
#  12  condition     2499 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 253.9+ KB

# %% [markdown]
# # pd.pivot_table(Data,index,columns,values)

# %%
pt=pd.pivot_table(df,index="year",columns="brand",values="mileage")

# %%
sns.heatmap(pt,annot=True,cmap="rocket")
# Out:
# <Axes: xlabel='brand', ylabel='year'>

# %%
print(df.corr())
# Out:
#             Unnamed: 0     price      year   mileage       lot
# Unnamed: 0    1.000000  0.098417  0.244921 -0.129258  0.012577
# price         0.098417  1.000000  0.418274 -0.400838  0.159369
# year          0.244921  0.418274  1.000000 -0.594686  0.164582
# mileage      -0.129258 -0.400838 -0.594686  1.000000 -0.130475
# lot           0.012577  0.159369  0.164582 -0.130475  1.000000
# C:\Users\hetvi\AppData\Local\Temp\ipykernel_12072\4212406737.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.corr())

# %%
corr=df.corr()
# Out:
# C:\Users\hetvi\AppData\Local\Temp\ipykernel_12072\1726683880.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()

# %%
sns.heatmap(corr,annot=True,cmap="rocket")
# Out:
# <Axes: >

# %%
df
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
corr
# Out:
#             Unnamed: 0     price      year   mileage       lot
# Unnamed: 0    1.000000  0.098417  0.244921 -0.129258  0.012577
# price         0.098417  1.000000  0.418274 -0.400838  0.159369
# year          0.244921  0.418274  1.000000 -0.594686  0.164582
# mileage      -0.129258 -0.400838 -0.594686  1.000000 -0.130475
# lot           0.012577  0.159369  0.164582 -0.130475  1.000000

# %%
sns.pairplot(df)

# %%
sns.catplot(df)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(df["price"])
# Out:
# <Axes: >

# %%
sns.distplot(df["price"])
# Out:
# C:\Users\hetvi\AppData\Local\Temp\ipykernel_12072\50337492.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
df["price"].skew()
# Out:
# 0.9227307836499805

# %%
sns.displot(df["price"])

# %%
sns.violinplot(df["price"])
# Out:
# <Axes: >

# %%
sns.pointplot(df["price"])
# Out:
# <Axes: >
